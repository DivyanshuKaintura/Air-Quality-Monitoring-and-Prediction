# %%
import pandas as pd

# %%
data = pd.read_csv('clean_city_day.csv')

# %%
data.shape
# Out:
# (24850, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24850 entries, 0 to 24849
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PM2.5       24850 non-null  float64
#  1   NO          24850 non-null  float64
#  2   NO2         24850 non-null  float64
#  3   NOx         24850 non-null  float64
#  4   CO          24850 non-null  float64
#  5   SO2         24850 non-null  float64
#  6   O3          24850 non-null  float64
#  7   Benzene     24850 non-null  float64
#  8   Toluene     24850 non-null  float64
#  9   AQI         24850 non-null  float64
#  10  AQI_Bucket  24850 non-null  object
# dtypes: float64(10), object(1)
# memory usage: 2.1+ MB

# %%
data.describe()
# Out:
#               PM2.5            NO           NO2           NOx            CO  \
# count  24850.000000  24850.000000  24850.000000  24850.000000  24850.000000
# mean      67.475903     17.621678     28.971818     32.290515      2.343536
# std       62.208948     22.245860     24.432587     29.542968      7.011582
# min        0.040000      0.030000      0.010000      0.000000      0.000000
# 25%       29.560000      5.720000     12.090000     14.030000      0.590000
# 50%       50.165000     10.075000     22.535000     25.720000      0.950000
# 75%       79.507500     19.710000     37.910000     38.170000      1.530000
# max      914.940000    390.680000    362.210000    378.240000    175.810000
#
#                 SO2            O3       Benzene       Toluene           AQI
# count  24850.000000  24850.000000  24850.000000  24850.000000  24850.000000
# mean      14.367049     34.899199      3.433371      9.332356    166.463581
# std       17.215237     21.368979     14.851776     18.273322    140.696585
# min        0.010000      0.010000      0.000000      0.000000     13.000000
# 25%        5.790000     19.640000      0.340000      1.580000     81.000000
# 50%        9.430000     32.060000      1.810000      6.790000    118.000000
# 75%       14.890000     45.397500      3.280840      8.700972    208.000000
# max      186.080000    257.730000    455.030000    454.850000   2049.000000

# %%
data.head()
# Out:
#     PM2.5     NO    NO2    NOx     CO    SO2      O3  Benzene  Toluene    AQI  \
# 0   83.13   6.93  28.71  33.72   6.93  49.52   59.76     0.02     0.00  209.0
# 1   79.84  13.85  28.68  41.08  13.85  48.49   97.07     0.04     0.00  328.0
# 2   94.52  24.39  32.66  52.61  24.39  67.39  111.33     0.24     0.01  514.0
# 3  135.99  43.48  42.08  84.57  43.48  75.23  102.70     0.40     0.04  782.0
# 4  178.33  54.56  35.31  72.80  54.56  55.04  107.38     0.46     0.06  914.0
#
#   AQI_Bucket
# 0       Poor
# 1  Very Poor
# 2     Severe
# 3     Severe
# 4     Severe

# %%
X = data.drop('AQI_Bucket', axis=1)
Y = data['AQI_Bucket']

# %%
X.shape
# Out:
# (24850, 10)

# %%
Y.shape
# Out:
# (24850,)

# %%
X.loc[[0]]
# Out:
#    PM2.5    NO    NO2    NOx    CO    SO2     O3  Benzene  Toluene    AQI
# 0  83.13  6.93  28.71  33.72  6.93  49.52  59.76     0.02      0.0  209.0

# %%
test1 = [83.13, 6.93, 28.71, 33.72, 49.52, 59.76, 0.02, 0.0, 209.0]

# %%
test2 = X.loc[[0]]

# %%
Y.loc[[0]]
# Out:
# 0    Poor
# Name: AQI_Bucket, dtype: object

# %%
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(42)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn import linear_model as lim

# %%
model = lim.LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# c:\Users\Abhinav\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_test, Y_test)
# Out:
# 0.4826961770623742

# %%
from sklearn import linear_model as lim
from sklearn import neighbors as nei
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm

# %%
# %%time
models = {"LogisticRegression": lim.LogisticRegression(),
          "KNN": nei.KNeighborsClassifier(),
          "Random Forest": RandomForestClassifier(),
          "Ridge Classification": lim.RidgeClassifier(),
          "SVM": svm.SVC()
          }

def scoreModel(models, train_x, test_x, train_y, test_y):
    np.random.seed(42)
    model_scores = {}
    for name, model in models.items():
      model.fit(train_x, train_y)
      model_scores[name] = model.score(test_x, test_y) * 100
    return model_scores
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
model_scores = scoreModel(models, X_train, X_test, Y_train, Y_test)
model_scores
# Out:
# c:\Users\Abhinav\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# {'LogisticRegression': 48.26961770623742,
#  'KNN': 95.6539235412475,
#  'Random Forest': 99.97987927565393,
#  'Ridge Classification': 57.54527162977867,
#  'SVM': 98.77263581488933}

# %%
model = RandomForestClassifier(n_estimators=100)

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
model.predict(test2)
# Out:
# array(['Poor'], dtype=object)

# %%
test2
# Out:
#    PM2.5    NO    NO2    NOx    CO    SO2     O3  Benzene  Toluene    AQI
# 0  83.13  6.93  28.71  33.72  6.93  49.52  59.76     0.02      0.0  209.0
